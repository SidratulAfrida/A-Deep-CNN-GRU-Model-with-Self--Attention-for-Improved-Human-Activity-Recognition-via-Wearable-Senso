# %% [markdown]
# # Import libraries

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from tensorflow.keras.utils import to_categorical

# %% [markdown]
# # Load the UCI-HAR dataset

# %%
train_data = pd.read_csv("X_train.txt", delim_whitespace=True, header=None)
train_labels = pd.read_csv("y_train.txt", header=None, names=['Activity'])

test_data = pd.read_csv("X_test.txt", delim_whitespace=True, header=None)
test_labels = pd.read_csv("y_test.txt", header=None, names=['Activity'])

# %% [markdown]
# # Merge features and labels

# %%
train_data['Activity'] = train_labels['Activity']
test_data['Activity'] = test_labels['Activity']

# %% [markdown]
# # Combine training and test sets

# %%
combined_data = pd.concat([train_data, test_data], ignore_index=True)

# %%
combined_data.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.288585 -0.020294 -0.132905 -0.995279 -0.983111 -0.913526 -0.995112
# 1  0.278419 -0.016411 -0.123520 -0.998245 -0.975300 -0.960322 -0.998807
# 2  0.279653 -0.019467 -0.113462 -0.995380 -0.967187 -0.978944 -0.996520
# 3  0.279174 -0.026201 -0.123283 -0.996091 -0.983403 -0.990675 -0.997099
# 4  0.276629 -0.016570 -0.115362 -0.998139 -0.980817 -0.990482 -0.998321
#
#           7         8         9  ...       552       553       554       555  \
# 0 -0.983185 -0.923527 -0.934724  ... -0.298676 -0.710304 -0.112754  0.030400
# 1 -0.974914 -0.957686 -0.943068  ... -0.595051 -0.861499  0.053477 -0.007435
# 2 -0.963668 -0.977469 -0.938692  ... -0.390748 -0.760104 -0.118559  0.177899
# 3 -0.982750 -0.989302 -0.938692  ... -0.117290 -0.482845 -0.036788 -0.012892
# 4 -0.979672 -0.990441 -0.942469  ... -0.351471 -0.699205  0.123320  0.122542
#
#         556       557       558       559       560  Activity
# 0 -0.464761 -0.018446 -0.841247  0.179941 -0.058627         5
# 1 -0.732626  0.703511 -0.844788  0.180289 -0.054317         5
# 2  0.100699  0.808529 -0.848933  0.180637 -0.049118         5
# 3  0.640011 -0.485366 -0.848649  0.181935 -0.047663         5
# 4  0.693578 -0.615971 -0.847865  0.185151 -0.043892         5
#
# [5 rows x 562 columns]

# %%
# Standardize features
scaler = StandardScaler()
combined_data.iloc[:, :-1] = scaler.fit_transform(combined_data.iloc[:, :-1])

# Encode activity labels
label_encoder = LabelEncoder()
combined_data['label'] = label_encoder.fit_transform(combined_data['Activity'])

# Convert labels to one-hot encoding
combined_data = pd.get_dummies(combined_data, columns=['label'])

# %%
# Display information about the dataset
print("Dataset Info:")
print(combined_data.info())
combined_data.head()
# Out:
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10299 entries, 0 to 10298
# Columns: 568 entries, 0 to label_5
# dtypes: bool(6), float64(561), int64(1)
# memory usage: 44.2 MB
# None
#           0         1         2         3         4         5         6  \
# 0  0.210534 -0.068703 -0.452195 -0.883335 -0.945431 -0.744387 -0.874687
# 1  0.060208  0.035902 -0.275222 -0.890098 -0.929817 -0.860322 -0.883627
# 2  0.078460 -0.046427 -0.085548 -0.883565 -0.913598 -0.906457 -0.878093
# 3  0.071375 -0.227794 -0.270741 -0.885188 -0.946015 -0.935521 -0.879495
# 4  0.033738  0.031617 -0.121380 -0.889855 -0.940846 -0.935041 -0.882451
#
#           7         8         9  ...       558       559       560  Activity  \
# 0 -0.944877 -0.773250 -0.868773  ... -0.674432  0.382008 -0.016151         5
# 1 -0.927796 -0.858859 -0.884263  ... -0.681360  0.383148 -0.000121         5
# 2 -0.904569 -0.908437 -0.876139  ... -0.689471  0.384289  0.019214         5
# 3 -0.943980 -0.938095 -0.876139  ... -0.688915  0.388536  0.024624         5
# 4 -0.937622 -0.940948 -0.883152  ... -0.687381  0.399066  0.038649         5
#
#    label_0  label_1  label_2  label_3  label_4  label_5
# 0    False    False    False    False     True    False
# 1    False    False    False    False     True    False
# 2    False    False    False    False     True    False
# 3    False    False    False    False     True    False
# 4    False    False    False    False     True    False
#
# [5 rows x 568 columns]

# %% [markdown]
# # Reshape for CNN-GRU Model

# %%
import numpy as np
# Separate features and labels
X = combined_data.iloc[:, :-6]  # Exclude one-hot encoded activity labels
y = combined_data.iloc[:, -6:]  # Extract one-hot encoded activity labels
# Reshape data for CNN-GRU model
X_reshaped = X.values.reshape((X.shape[0], 1, X.shape[1]))
y_array = np.array(y)
# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_reshaped, y_array, test_size=0.2, random_state=42)

# %% [markdown]
# # Segmentation

# %%
import numpy as np

def segment_data(data, labels, window_size, overlap):
   

    num_samples, num_time_steps, num_features = data.shape
    step_size = int(window_size * (1 - overlap))

    # Calculate the number of windows
    num_windows = int((num_time_steps - window_size) / step_size) + 1

    # Initialize arrays to store segmented data and labels
    segmented_data = np.zeros((num_samples * num_windows, window_size, num_features))
    segmented_labels = np.zeros(num_samples * num_windows)

    # Iterate through each sample
    for i in range(num_samples):
        sample_data = data[i]
        label = labels[i]

        # Iterate through each window
        for j in range(num_windows):
            start = j * step_size
            end = start + window_size

            # Extract the window from the original data
            window_data = sample_data[start:end, :]

            # Store the segmented data and label
            index = i * num_windows + j
            segmented_data[index] = window_data
            segmented_labels[index] = label

    return segmented_data, segmented_labels

# Assuming X_train and y_train are your training data and labels
# Specify the window size and overlap
window_size = 128  # Adjust as needed
overlap = 0.5  # Adjust as needed

# Segment the training data
X_train_segmented, y_train_segmented = segment_data(X_train, y_train, window_size, overlap)

# %% [markdown]
# # Linear Interpolation

# %%
import pandas as pd
import numpy as np
# Flatten the time steps for each sample
X_train_flattened = X_train.reshape((X_train.shape[0], -1))

# Convert to a DataFrame for easier interpolation
df_train = pd.DataFrame(X_train_flattened)

# Perform linear interpolation
df_train.interpolate(method='linear', axis=1, inplace=True)

# Reshape the interpolated data back to the original shape
X_train_interpolated = df_train.values.reshape(X_train.shape)

# Check for NaN values after interpolation
if np.isnan(X_train_interpolated).any():
    print("Warning: NaN values still present after interpolation.")

# %% [markdown]
# # Normalization

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

# Normalize the data using Min-Max scaling
scaler = MinMaxScaler()
df_train_normalized = pd.DataFrame(scaler.fit_transform(df_train), columns=df_train.columns)

# Plot the original and normalized data for comparison
plt.subplot(2, 1, 1)
plt.plot(df_train)
plt.title('Before Normalization')
plt.legend()

plt.subplot(2, 1, 2)
plt.plot(df_train_normalized,color='blue')
plt.title('After Normalization')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# Assuming df_train is the original dataset
# Replace this with  actual dataset or provide its definition

# Create a hypothetical DataFrame for illustration
data = {'Feature1': [1, 2, 3, 4, 5, 6],
        'Feature2': [5, 4, 3, 6, 1, 2],
        'Activity': ['Walking', 'Sitting', 'Laying', 'Walking Downstairs','Standing', 'Walking Upstairs']}

df_train = pd.DataFrame(data)

# Separate the features and the target variable
X = df_train.drop('Activity', axis=1)
y = df_train['Activity']

# Normalize the data using Min-Max scaling
scaler = MinMaxScaler()
X_normalized = pd.DataFrame(scaler.fit_transform(X), columns=X.columns)

# Display the first few rows of the normalized dataset
print("\nNormalized Data:")
print(X_normalized.head())

# Concatenate the normalized features with the target variable
df_normalized = pd.concat([X_normalized, y], axis=1)

# Display the first few rows of the dataset with normalized features
print("\nNormalized Data with Target Variable:")
print(df_normalized.head())

# Optionally, you can visualize the distribution of the normalized features
X_normalized.hist(bins=20, figsize=(10, 6))
plt.suptitle("Histogram of Normalized Features")
plt.show()
# Out:
# Normalized Data:
#    Feature1  Feature2
# 0       0.0       0.8
# 1       0.2       0.6
# 2       0.4       0.4
# 3       0.6       1.0
# 4       0.8       0.0
#
# Normalized Data with Target Variable:
#    Feature1  Feature2            Activity
# 0       0.0       0.8             Walking
# 1       0.2       0.6             Sitting
# 2       0.4       0.4              Laying
# 3       0.6       1.0  Walking Downstairs
# 4       0.8       0.0            Standing

# %% [markdown]
# # Build CNN -GRU

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, GRU, Dense, Flatten
model = Sequential()

# %%
from keras.models import Sequential
from keras.layers import Conv1D, MaxPooling1D, GRU, Dense, Flatten, Dropout
from keras.regularizers import l2
from keras.optimizers import Adam
from keras.layers import Dense, GlobalAveragePooling1D, BatchNormalization, MaxPool1D, Reshape, Activation

from tensorflow.keras.layers import Layer, Concatenate

class SelfAttention(Layer):
    def __init__(self, **kwargs):
        super(SelfAttention, self).__init__(**kwargs)

    def build(self, input_shape):
        super(SelfAttention, self).build(input_shape)

    def call(self, inputs, **kwargs):
        # Use the same input as both query and value
        query_value = inputs
        attention = Concatenate()([query_value, query_value])  # Concatenate query and value
        return attention

    def compute_output_shape(self, input_shape):
        return input_shape

model = Sequential()

# Add Conv1D layer
model.add(Conv1D(filters=32, kernel_size=3, activation='relu', input_shape=((X_train.shape[1], X_train.shape[2])), padding='same', kernel_regularizer=l2(0.01)))
model.add(BatchNormalization())
model.add(Dropout(0.5))

# Add GRU layer (return_sequences=True is important)
model.add(GRU(50, return_sequences=True, kernel_regularizer=l2(0.01)))
model.add(Dropout(0.5))


# Add Self-Attention layer
model.add(SelfAttention())

#Add GRU layer
model.add(GRU(50, return_sequences=True, kernel_regularizer=l2(0.01)))
model.add(Dropout(0.5))

# Flatten the output
model.add(Flatten())

# Fully connected layer
model.add(Dense(100, activation='relu'))
model.add(Dropout(0.5))

# Output layer
model.add(Dense(6, activation='softmax'))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 1, 32)             53984
#
#  batch_normalization (BatchN  (None, 1, 32)            128
#  ormalization)
#
#  dropout (Dropout)           (None, 1, 32)             0
#
#  gru (GRU)                   (None, 1, 50)             12600
#
#  dropout_1 (Dropout)         (None, 1, 50)             0
#
#  self_attention (SelfAttenti  (None, 1, 100)           0
#  on)
#
#  gru_1 (GRU)                 (None, 1, 50)             22800
#
#  dropout_2 (Dropout)         (None, 1, 50)             0
#
#  flatten (Flatten)           (None, 50)                0
#
#  dense (Dense)               (None, 100)               5100
#
#  dropout_3 (Dropout)         (None, 100)               0
#
#  dense_1 (Dense)             (None, 6)                 606
#
# =================================================================
# Total params: 95,218
# Trainable params: 95,154
# Non-trainable params: 64
# _________________________________________________________________

# %%
opt = Adam(learning_rate=0.001)
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
history = model.fit(X_train, y_train,
          batch_size=500,
          epochs=100,
          validation_data=(X_test, y_test),
          verbose=1)
# Out:
# Epoch 1/100
# 17/17 [==============================] - 8s 117ms/step - loss: 3.6919 - accuracy: 0.2794 - val_loss: 3.0954 - val_accuracy: 0.6058
# Epoch 2/100
# 17/17 [==============================] - 0s 18ms/step - loss: 2.7487 - accuracy: 0.4468 - val_loss: 2.2351 - val_accuracy: 0.6345
# Epoch 3/100
# 17/17 [==============================] - 0s 18ms/step - loss: 2.0495 - accuracy: 0.5473 - val_loss: 1.6738 - val_accuracy: 0.6961
# Epoch 4/100
# 17/17 [==============================] - 0s 16ms/step - loss: 1.5769 - accuracy: 0.6636 - val_loss: 1.2923 - val_accuracy: 0.8306
# Epoch 5/100
# 17/17 [==============================] - 0s 16ms/step - loss: 1.2045 - accuracy: 0.7812 - val_loss: 0.9569 - val_accuracy: 0.8660
# Epoch 6/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.9204 - accuracy: 0.8500 - val_loss: 0.7418 - val_accuracy: 0.8903
# Epoch 7/100
# 17/17 [==============================] - 0s 15ms/step - loss: 0.7320 - accuracy: 0.8940 - val_loss: 0.5642 - val_accuracy: 0.9578
# Epoch 8/100
# 17/17 [==============================] - 0s 14ms/step - loss: 0.6052 - accuracy: 0.9158 - val_loss: 0.4664 - val_accuracy: 0.9597
# Epoch 9/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.5127 - accuracy: 0.9292 - val_loss: 0.3746 - val_accuracy: 0.9694
# Epoch 10/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.4476 - accuracy: 0.9364 - val_loss: 0.3506 - val_accuracy: 0.9626
# Epoch 11/100
# 17/17 [==============================] - 0s 15ms/step - loss: 0.3900 - accuracy: 0.9440 - val_loss: 0.2895 - val_accuracy: 0.9723
# Epoch 12/100
# 17/17 [==============================] - 0s 20ms/step - loss: 0.3471 - accuracy: 0.9523 - val_loss: 0.2464 - val_accuracy: 0.9786
# Epoch 13/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.3143 - accuracy: 0.9614 - val_loss: 0.2311 - val_accuracy: 0.9796
# Epoch 14/100
# 17/17 [==============================] - 0s 15ms/step - loss: 0.2896 - accuracy: 0.9591 - val_loss: 0.2244 - val_accuracy: 0.9757
# Epoch 15/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.2836 - accuracy: 0.9576 - val_loss: 0.1978 - val_accuracy: 0.9811
# Epoch 16/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.2605 - accuracy: 0.9633 - val_loss: 0.1770 - val_accuracy: 0.9830
# Epoch 17/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.2525 - accuracy: 0.9632 - val_loss: 0.1787 - val_accuracy: 0.9811
# Epoch 18/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.2425 - accuracy: 0.9630 - val_loss: 0.1664 - val_accuracy: 0.9845
# Epoch 19/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.2299 - accuracy: 0.9642 - val_loss: 0.1543 - val_accuracy: 0.9869
# Epoch 20/100
# 17/17 [==============================] - 0s 15ms/step - loss: 0.2177 - accuracy: 0.9682 - val_loss: 0.1494 - val_accuracy: 0.9869
# Epoch 21/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.2151 - accuracy: 0.9665 - val_loss: 0.1540 - val_accuracy: 0.9806
# Epoch 22/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.2107 - accuracy: 0.9665 - val_loss: 0.1381 - val_accuracy: 0.9893
# Epoch 23/100
# 17/17 [==============================] - 0s 15ms/step - loss: 0.2024 - accuracy: 0.9670 - val_loss: 0.1352 - val_accuracy: 0.9883
# Epoch 24/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.1957 - accuracy: 0.9724 - val_loss: 0.1268 - val_accuracy: 0.9903
# Epoch 25/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.1887 - accuracy: 0.9723 - val_loss: 0.1205 - val_accuracy: 0.9908
# Epoch 26/100
# 17/17 [==============================] - 0s 15ms/step - loss: 0.1757 - accuracy: 0.9771 - val_loss: 0.1188 - val_accuracy: 0.9927
# Epoch 27/100
# 17/17 [==============================] - 0s 15ms/step - loss: 0.1872 - accuracy: 0.9718 - val_loss: 0.1222 - val_accuracy: 0.9903
# Epoch 28/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.1881 - accuracy: 0.9721 - val_loss: 0.1216 - val_accuracy: 0.9898
# Epoch 29/100
# 17/17 [==============================] - 0s 15ms/step - loss: 0.1923 - accuracy: 0.9705 - val_loss: 0.1321 - val_accuracy: 0.9864
# Epoch 30/100
# 17/17 [==============================] - 0s 15ms/step - loss: 0.1818 - accuracy: 0.9740 - val_loss: 0.1173 - val_accuracy: 0.9922
# Epoch 31/100
# 17/17 [==============================] - 0s 15ms/step - loss: 0.1686 - accuracy: 0.9756 - val_loss: 0.2149 - val_accuracy: 0.9544
# Epoch 32/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.1844 - accuracy: 0.9715 - val_loss: 0.1141 - val_accuracy: 0.9913
# Epoch 33/100
# 17/17 [==============================] - 0s 15ms/step - loss: 0.1705 - accuracy: 0.9763 - val_loss: 0.1085 - val_accuracy: 0.9947
# Epoch 34/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.1611 - accuracy: 0.9774 - val_loss: 0.1022 - val_accuracy: 0.9961
# Epoch 35/100
# 17/17 [==============================] - 0s 15ms/step - loss: 0.1555 - accuracy: 0.9785 - val_loss: 0.1021 - val_accuracy: 0.9942
# Epoch 36/100
# 17/17 [==============================] - 0s 19ms/step - loss: 0.1596 - accuracy: 0.9780 - val_loss: 0.1080 - val_accuracy: 0.9932
# Epoch 37/100
# 17/17 [==============================] - 0s 20ms/step - loss: 0.1503 - accuracy: 0.9808 - val_loss: 0.1161 - val_accuracy: 0.9883
# Epoch 38/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.1584 - accuracy: 0.9769 - val_loss: 0.1023 - val_accuracy: 0.9942
# Epoch 39/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.1496 - accuracy: 0.9799 - val_loss: 0.1093 - val_accuracy: 0.9903
# Epoch 40/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.1585 - accuracy: 0.9756 - val_loss: 0.0991 - val_accuracy: 0.9927
# Epoch 41/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.1481 - accuracy: 0.9789 - val_loss: 0.0954 - val_accuracy: 0.9942
# Epoch 42/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.1472 - accuracy: 0.9791 - val_loss: 0.1081 - val_accuracy: 0.9869
# Epoch 43/100
# 17/17 [==============================] - 0s 15ms/step - loss: 0.1580 - accuracy: 0.9760 - val_loss: 0.1003 - val_accuracy: 0.9932
# Epoch 44/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.1526 - accuracy: 0.9762 - val_loss: 0.1136 - val_accuracy: 0.9898
# Epoch 45/100
# 17/17 [==============================] - 0s 15ms/step - loss: 0.1618 - accuracy: 0.9740 - val_loss: 0.0940 - val_accuracy: 0.9951
# Epoch 46/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.1516 - accuracy: 0.9744 - val_loss: 0.1008 - val_accuracy: 0.9937
# Epoch 47/100
# 17/17 [==============================] - 0s 15ms/step - loss: 0.1466 - accuracy: 0.9782 - val_loss: 0.0955 - val_accuracy: 0.9951
# Epoch 48/100
# 17/17 [==============================] - 0s 15ms/step - loss: 0.1559 - accuracy: 0.9732 - val_loss: 0.0927 - val_accuracy: 0.9947
# Epoch 49/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.1421 - accuracy: 0.9795 - val_loss: 0.1001 - val_accuracy: 0.9937
# Epoch 50/100
# 17/17 [==============================] - 0s 15ms/step - loss: 0.1473 - accuracy: 0.9799 - val_loss: 0.1056 - val_accuracy: 0.9883
# Epoch 51/100
# 17/17 [==============================] - 0s 15ms/step - loss: 0.1403 - accuracy: 0.9818 - val_loss: 0.0921 - val_accuracy: 0.9971
# Epoch 52/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.1412 - accuracy: 0.9791 - val_loss: 0.1652 - val_accuracy: 0.9655
# Epoch 53/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.1368 - accuracy: 0.9786 - val_loss: 0.0896 - val_accuracy: 0.9947
# Epoch 54/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.1329 - accuracy: 0.9833 - val_loss: 0.0939 - val_accuracy: 0.9947
# Epoch 55/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.1390 - accuracy: 0.9807 - val_loss: 0.0853 - val_accuracy: 0.9971
# Epoch 56/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.1395 - accuracy: 0.9789 - val_loss: 0.0965 - val_accuracy: 0.9927
# Epoch 57/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.1312 - accuracy: 0.9835 - val_loss: 0.1191 - val_accuracy: 0.9859
# Epoch 58/100
# 17/17 [==============================] - 0s 15ms/step - loss: 0.1351 - accuracy: 0.9820 - val_loss: 0.0914 - val_accuracy: 0.9937
# Epoch 59/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.1356 - accuracy: 0.9794 - val_loss: 0.0852 - val_accuracy: 0.9956
# Epoch 60/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.1301 - accuracy: 0.9842 - val_loss: 0.0835 - val_accuracy: 0.9966
# Epoch 61/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.1278 - accuracy: 0.9834 - val_loss: 0.0829 - val_accuracy: 0.9971
# Epoch 62/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.1252 - accuracy: 0.9829 - val_loss: 0.0839 - val_accuracy: 0.9966
# Epoch 63/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.1270 - accuracy: 0.9856 - val_loss: 0.0876 - val_accuracy: 0.9951
# Epoch 64/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.1218 - accuracy: 0.9835 - val_loss: 0.0952 - val_accuracy: 0.9937
# Epoch 65/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.1183 - accuracy: 0.9859 - val_loss: 0.0802 - val_accuracy: 0.9966
# Epoch 66/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.1197 - accuracy: 0.9852 - val_loss: 0.1434 - val_accuracy: 0.9748
# Epoch 67/100
# 17/17 [==============================] - 0s 15ms/step - loss: 0.1399 - accuracy: 0.9751 - val_loss: 0.0780 - val_accuracy: 0.9966
# Epoch 68/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.1441 - accuracy: 0.9749 - val_loss: 0.0766 - val_accuracy: 0.9971
# Epoch 69/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.1300 - accuracy: 0.9813 - val_loss: 0.0829 - val_accuracy: 0.9961
# Epoch 70/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.1262 - accuracy: 0.9843 - val_loss: 0.0784 - val_accuracy: 0.9971
# Epoch 71/100
# 17/17 [==============================] - 0s 15ms/step - loss: 0.1243 - accuracy: 0.9831 - val_loss: 0.0872 - val_accuracy: 0.9942
# Epoch 72/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.1271 - accuracy: 0.9829 - val_loss: 0.0865 - val_accuracy: 0.9961
# Epoch 73/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.1135 - accuracy: 0.9865 - val_loss: 0.0826 - val_accuracy: 0.9956
# Epoch 74/100
# 17/17 [==============================] - 0s 19ms/step - loss: 0.1140 - accuracy: 0.9875 - val_loss: 0.0851 - val_accuracy: 0.9947
# Epoch 75/100
# 17/17 [==============================] - 0s 19ms/step - loss: 0.1223 - accuracy: 0.9823 - val_loss: 0.0734 - val_accuracy: 0.9971
# Epoch 76/100
# 17/17 [==============================] - 0s 19ms/step - loss: 0.1252 - accuracy: 0.9811 - val_loss: 0.0857 - val_accuracy: 0.9942
# Epoch 77/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.1274 - accuracy: 0.9812 - val_loss: 0.0888 - val_accuracy: 0.9922
# Epoch 78/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.1328 - accuracy: 0.9820 - val_loss: 0.0858 - val_accuracy: 0.9956
# Epoch 79/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.1197 - accuracy: 0.9836 - val_loss: 0.0790 - val_accuracy: 0.9971
# Epoch 80/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.1197 - accuracy: 0.9845 - val_loss: 0.0742 - val_accuracy: 0.9976
# Epoch 81/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.1182 - accuracy: 0.9842 - val_loss: 0.0851 - val_accuracy: 0.9951
# Epoch 82/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.1156 - accuracy: 0.9840 - val_loss: 0.0758 - val_accuracy: 0.9976
# Epoch 83/100
# 17/17 [==============================] - 0s 15ms/step - loss: 0.1108 - accuracy: 0.9843 - val_loss: 0.0738 - val_accuracy: 0.9985
# Epoch 84/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.1201 - accuracy: 0.9854 - val_loss: 0.0976 - val_accuracy: 0.9917
# Epoch 85/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.1212 - accuracy: 0.9837 - val_loss: 0.0791 - val_accuracy: 0.9976
# Epoch 86/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.1103 - accuracy: 0.9848 - val_loss: 0.0877 - val_accuracy: 0.9922
# Epoch 87/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.1049 - accuracy: 0.9880 - val_loss: 0.0714 - val_accuracy: 0.9985
# Epoch 88/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.1139 - accuracy: 0.9846 - val_loss: 0.0760 - val_accuracy: 0.9971
# Epoch 89/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.1146 - accuracy: 0.9825 - val_loss: 0.0751 - val_accuracy: 0.9966
# Epoch 90/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.1198 - accuracy: 0.9811 - val_loss: 0.0920 - val_accuracy: 0.9903
# Epoch 91/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.1137 - accuracy: 0.9849 - val_loss: 0.0730 - val_accuracy: 0.9971
# Epoch 92/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.1065 - accuracy: 0.9866 - val_loss: 0.0727 - val_accuracy: 0.9966
# Epoch 93/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.1044 - accuracy: 0.9869 - val_loss: 0.0731 - val_accuracy: 0.9976
# Epoch 94/100
# 17/17 [==============================] - 0s 19ms/step - loss: 0.1182 - accuracy: 0.9822 - val_loss: 0.0928 - val_accuracy: 0.9903
# Epoch 95/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.1367 - accuracy: 0.9754 - val_loss: 0.0854 - val_accuracy: 0.9947
# Epoch 96/100
# 17/17 [==============================] - 0s 15ms/step - loss: 0.1323 - accuracy: 0.9780 - val_loss: 0.0858 - val_accuracy: 0.9966
# Epoch 97/100
# 17/17 [==============================] - 0s 15ms/step - loss: 0.1354 - accuracy: 0.9775 - val_loss: 0.0808 - val_accuracy: 0.9956
# Epoch 98/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.1384 - accuracy: 0.9792 - val_loss: 0.0778 - val_accuracy: 0.9966
# Epoch 99/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.1312 - accuracy: 0.9783 - val_loss: 0.0988 - val_accuracy: 0.9913
# Epoch 100/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.1283 - accuracy: 0.9806 - val_loss: 0.0777 - val_accuracy: 0.9966

# %%
name = 'model'
model.save(name+'.h5')
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='lower left')
plt.savefig(name+'_acc.png')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.savefig(name+'_loss.png')
plt.show()

# %%
import mlxtend
from mlxtend.plotting import plot_confusion_matrix
from sklearn.metrics import confusion_matrix

# %%
from sklearn.metrics import confusion_matrix
import numpy as np


score = model.evaluate(X_test, y_test)
print("Accuracy: ", score[1])
print("Loss: ", score[0])
print(confusion_matrix(np.argmax(y_test, axis=1), np.argmax(model.predict(X_test), axis=1)))
# Out:
# 65/65 [==============================] - 0s 3ms/step - loss: 0.0777 - accuracy: 0.9966
# Accuracy:  0.996601939201355
# Loss:  0.07774677127599716
# 65/65 [==============================] - 1s 2ms/step
# [[366   2   1   0   0   0]
#  [  1 269   0   0   0   0]
#  [  0   0 284   0   0   0]
#  [  0   1   0 375   1   0]
#  [  0   0   0   1 353   0]
#  [  0   0   0   0   0 406]]

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

# Assuming y_true_test contains your true labels for the test set
y_true_test = np.argmax(y_test, axis=1)

# Assuming y_pred_test_classes is the predicted labels for the test set
y_pred_test = model.predict(X_test)
y_pred_test_classes = np.argmax(y_pred_test, axis=1)

# Compute confusion matrix for the test set
confusion_matrix_test = confusion_matrix(y_true_test, y_pred_test_classes)

# Create a DataFrame from the confusion matrix
confusion_matrix_df_test = pd.DataFrame(data=confusion_matrix_test,
                                        columns=['WALK', 'UP', 'DOWN', 'STAND', 'SITTING', 'LAYING'],
                                        index=['WALK', 'UP', 'DOWN', 'STAND', 'SITTING', 'LAYING'])

# Plot the heatmap for the test set
plt.figure(figsize=(6, 4))
sns.heatmap(confusion_matrix_df_test, annot=True, fmt='d', cmap="Blues", linecolor="DarkBlue", linewidths=0.55)
plt.title('Confusion Matrix - Test Set')
plt.show()
# Out:
# 65/65 [==============================] - 0s 2ms/step

# %%
from sklearn.metrics import classification_report
#print(classification_report(y_true_test, y_pred_test_classes))

# %%
report = classification_report(y_true_test, y_pred_test_classes, output_dict=True)

# %%
print (report)
# Out:
# {'0': {'precision': 0.997275204359673, 'recall': 0.991869918699187, 'f1-score': 0.9945652173913043, 'support': 369}, '1': {'precision': 0.9889705882352942, 'recall': 0.9962962962962963, 'f1-score': 0.9926199261992621, 'support': 270}, '2': {'precision': 0.9964912280701754, 'recall': 1.0, 'f1-score': 0.9982425307557118, 'support': 284}, '3': {'precision': 0.9973404255319149, 'recall': 0.9946949602122016, 'f1-score': 0.9960159362549801, 'support': 377}, '4': {'precision': 0.9971751412429378, 'recall': 0.9971751412429378, 'f1-score': 0.9971751412429379, 'support': 354}, '5': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 406}, 'accuracy': 0.9966019417475728, 'macro avg': {'precision': 0.9962087645733325, 'recall': 0.9966727194084372, 'f1-score': 0.9964364586406993, 'support': 2060}, 'weighted avg': {'precision': 0.9966104167134517, 'recall': 0.9966019417475728, 'f1-score': 0.996602345628127, 'support': 2060}}

# %%
report_df = pd.DataFrame(report).transpose()

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd


# Extract metrics for each class
precision = report_df['precision'][:-3]
recall = report_df['recall'][:-3]
f1_score = report_df['f1-score'][:-3]
support = report_df['support'][:-3]

# Plot precision, recall, f1-score, and support
fig, axes = plt.subplots(2, 2, figsize=(14, 10))

precision.plot(kind='bar', ax=axes[0, 0], title='Precision by Class', color='skyblue')
axes[0, 0].set_ylabel('Precision')

recall.plot(kind='bar', ax=axes[0, 1], title='Recall by Class', color='lightgreen')
axes[0, 1].set_ylabel('Recall')

f1_score.plot(kind='bar', ax=axes[1, 0], title='F1 Score by Class', color='salmon')
axes[1, 0].set_ylabel('F1 Score')

support.plot(kind='bar', ax=axes[1, 1], title='Support by Class', color='orange')
axes[1, 1].set_ylabel('Support')

plt.tight_layout()
plt.show()

# %%
from keras.models import Sequential
from keras.layers import Conv1D, GRU, Dense, Flatten, Dropout, BatchNormalization
from keras.optimizers import Adam, Adagrad, SGD, RMSprop
from keras.callbacks import EarlyStopping
from keras.regularizers import l2
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

# Ensure TensorFlow version is correct
print(tf.__version__)

# Define X_train, y_train, X_test, y_test here
# Example:
# X_train = ...
# y_train = ...
# X_test = ...
# y_test = ...

# Function to create the model
def create_model():
    model = Sequential()
    model.add(Conv1D(filters=32, kernel_size=3, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), padding='same', kernel_regularizer=l2(0.01)))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))
    model.add(GRU(50, return_sequences=True, kernel_regularizer=l2(0.01)))
    model.add(Dropout(0.5))
    model.add(GRU(50, return_sequences=True, kernel_regularizer=l2(0.01)))
    model.add(Dropout(0.5))
    model.add(Flatten())
    model.add(Dense(100, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(6, activation='softmax'))
    return model

# List of optimizers to evaluate
optimizers = {
    'Adam': Adam(learning_rate=0.001),
    'Adagrad': Adagrad(learning_rate=0.001),
    'SGD': SGD(learning_rate=0.001),
    'RMSprop': RMSprop(learning_rate=0.001)
}

# Dictionary to store final accuracy and loss of each optimizer
final_metrics = {
    'optimizer': [],
    'train_accuracy': [],
    'val_accuracy': [],
    'train_loss': [],
    'val_loss': []
}

# Dictionary to store histories
histories = {}

# Train and evaluate the model with each optimizer
for opt_name, opt in optimizers.items():
    print(f'Training with {opt_name} optimizer...')
    model = create_model()
    model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
    
    early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
    
    history = model.fit(X_train, y_train, epochs=100, validation_data=(X_test, y_test), verbose=1, callbacks=[early_stopping])
    histories[opt_name] = history
    
    # Store the final metrics
    final_metrics['optimizer'].append(opt_name)
    final_metrics['train_accuracy'].append(history.history['accuracy'][-1])
    final_metrics['val_accuracy'].append(history.history['val_accuracy'][-1])
    final_metrics['train_loss'].append(history.history['loss'][-1])
    final_metrics['val_loss'].append(history.history['val_loss'][-1])
# Out:
# 2.12.0
# Training with Adam optimizer...
# Epoch 1/100
# 258/258 [==============================] - 8s 13ms/step - loss: 1.6807 - accuracy: 0.5030 - val_loss: 0.7547 - val_accuracy: 0.8587
# Epoch 2/100
# 258/258 [==============================] - 2s 9ms/step - loss: 0.7144 - accuracy: 0.7958 - val_loss: 0.3836 - val_accuracy: 0.9510
# Epoch 3/100
# 258/258 [==============================] - 2s 8ms/step - loss: 0.5279 - accuracy: 0.8814 - val_loss: 0.3197 - val_accuracy: 0.9641
# Epoch 4/100
# 258/258 [==============================] - 2s 9ms/step - loss: 0.4803 - accuracy: 0.9016 - val_loss: 0.2936 - val_accuracy: 0.9675
# Epoch 5/100
# 258/258 [==============================] - 2s 8ms/step - loss: 0.4317 - accuracy: 0.9189 - val_loss: 0.3049 - val_accuracy: 0.9612
# Epoch 6/100
# 258/258 [==============================] - 2s 9ms/step - loss: 0.4436 - accuracy: 0.9099 - val_loss: 0.2526 - val_accuracy: 0.9806
# Epoch 7/100
# 258/258 [==============================] - 2s 10ms/step - loss: 0.4108 - accuracy: 0.9203 - val_loss: 0.2437 - val_accuracy: 0.9806
# Epoch 8/100
# 258/258 [==============================] - 2s 8ms/step - loss: 0.3617 - accuracy: 0.9354 - val_loss: 0.2315 - val_accuracy: 0.9820
# Epoch 9/100
# 258/258 [==============================] - 2s 7ms/step - loss: 0.3547 - accuracy: 0.9353 - val_loss: 0.2402 - val_accuracy: 0.9752
# Epoch 10/100
# 258/258 [==============================] - 2s 8ms/step - loss: 0.3855 - accuracy: 0.9281 - val_loss: 0.2256 - val_accuracy: 0.9811
# Epoch 11/100
# 258/258 [==============================] - 2s 6ms/step - loss: 0.3433 - accuracy: 0.9416 - val_loss: 0.2824 - val_accuracy: 0.9631
# Epoch 12/100
# 258/258 [==============================] - 2s 6ms/step - loss: 0.3861 - accuracy: 0.9269 - val_loss: 0.3202 - val_accuracy: 0.9374
# Epoch 13/100
# 258/258 [==============================] - 2s 7ms/step - loss: 0.3787 - accuracy: 0.9298 - val_loss: 0.2770 - val_accuracy: 0.9631
# Epoch 14/100
# 258/258 [==============================] - 2s 7ms/step - loss: 0.3521 - accuracy: 0.9402 - val_loss: 0.2290 - val_accuracy: 0.9811
# Epoch 15/100
# 258/258 [==============================] - 2s 7ms/step - loss: 0.3691 - accuracy: 0.9372 - val_loss: 0.2515 - val_accuracy: 0.9762
# Epoch 16/100
# 258/258 [==============================] - 2s 7ms/step - loss: 0.3624 - accuracy: 0.9388 - val_loss: 0.2215 - val_accuracy: 0.9806
# Epoch 17/100
# 258/258 [==============================] - 2s 7ms/step - loss: 0.3372 - accuracy: 0.9414 - val_loss: 0.2046 - val_accuracy: 0.9859
# Epoch 18/100
# 258/258 [==============================] - 2s 7ms/step - loss: 0.3446 - accuracy: 0.9396 - val_loss: 0.2237 - val_accuracy: 0.9811
# Epoch 19/100
# 258/258 [==============================] - 2s 7ms/step - loss: 0.3637 - accuracy: 0.9389 - val_loss: 0.2078 - val_accuracy: 0.9879
# Epoch 20/100
# 258/258 [==============================] - 2s 6ms/step - loss: 0.3192 - accuracy: 0.9498 - val_loss: 0.2866 - val_accuracy: 0.9510
# Epoch 21/100
# 258/258 [==============================] - 2s 7ms/step - loss: 0.3381 - accuracy: 0.9419 - val_loss: 0.2721 - val_accuracy: 0.9621
# Epoch 22/100
# 258/258 [==============================] - 2s 6ms/step - loss: 0.3362 - accuracy: 0.9442 - val_loss: 0.2242 - val_accuracy: 0.9786
# Epoch 23/100
# 258/258 [==============================] - 2s 7ms/step - loss: 0.3320 - accuracy: 0.9443 - val_loss: 0.2073 - val_accuracy: 0.9845
# Epoch 24/100
# 258/258 [==============================] - 2s 7ms/step - loss: 0.3304 - accuracy: 0.9427 - val_loss: 0.2103 - val_accuracy: 0.9850
# Epoch 25/100
# 258/258 [==============================] - 2s 6ms/step - loss: 0.3384 - accuracy: 0.9449 - val_loss: 0.2218 - val_accuracy: 0.9791
# Epoch 26/100
# 258/258 [==============================] - 2s 8ms/step - loss: 0.3402 - accuracy: 0.9408 - val_loss: 0.4029 - val_accuracy: 0.9102
# Epoch 27/100
# 258/258 [==============================] - 2s 9ms/step - loss: 0.3635 - accuracy: 0.9339 - val_loss: 0.2327 - val_accuracy: 0.9748
# Training with Adagrad optimizer...
# Epoch 1/100
# 258/258 [==============================] - 19s 11ms/step - loss: 3.5989 - accuracy: 0.2205 - val_loss: 3.4985 - val_accuracy: 0.4092
# Epoch 2/100
# 258/258 [==============================] - 2s 6ms/step - loss: 3.4850 - accuracy: 0.2766 - val_loss: 3.3652 - val_accuracy: 0.4155
# Epoch 3/100
# 258/258 [==============================] - 2s 6ms/step - loss: 3.3728 - accuracy: 0.3220 - val_loss: 3.2390 - val_accuracy: 0.4180
# Epoch 4/100
# 258/258 [==============================] - 2s 7ms/step - loss: 3.2561 - accuracy: 0.3716 - val_loss: 3.1116 - val_accuracy: 0.4194
# Epoch 5/100
# 258/258 [==============================] - 2s 8ms/step - loss: 3.1518 - accuracy: 0.3735 - val_loss: 2.9912 - val_accuracy: 0.4228
# Epoch 6/100
# 258/258 [==============================] - 2s 6ms/step - loss: 3.0468 - accuracy: 0.3924 - val_loss: 2.8792 - val_accuracy: 0.4461
# Epoch 7/100
# 258/258 [==============================] - 2s 6ms/step - loss: 2.9486 - accuracy: 0.4156 - val_loss: 2.7772 - val_accuracy: 0.4752
# Epoch 8/100
# 258/258 [==============================] - 2s 7ms/step - loss: 2.8590 - accuracy: 0.4268 - val_loss: 2.6861 - val_accuracy: 0.5058
# Epoch 9/100
# 258/258 [==============================] - 2s 6ms/step - loss: 2.7753 - accuracy: 0.4419 - val_loss: 2.6039 - val_accuracy: 0.5325
# Epoch 10/100
# 258/258 [==============================] - 2s 7ms/step - loss: 2.7004 - accuracy: 0.4427 - val_loss: 2.5273 - val_accuracy: 0.5612
# Epoch 11/100
# 258/258 [==============================] - 2s 6ms/step - loss: 2.6294 - accuracy: 0.4615 - val_loss: 2.4559 - val_accuracy: 0.6024
# Epoch 12/100
# 258/258 [==============================] - 2s 7ms/step - loss: 2.5639 - accuracy: 0.4655 - val_loss: 2.3892 - val_accuracy: 0.6592
# Epoch 13/100
# 258/258 [==============================] - 3s 10ms/step - loss: 2.5050 - accuracy: 0.4808 - val_loss: 2.3247 - val_accuracy: 0.6966
# Epoch 14/100
# 258/258 [==============================] - 3s 11ms/step - loss: 2.4435 - accuracy: 0.4987 - val_loss: 2.2630 - val_accuracy: 0.7272
# Epoch 15/100
# 258/258 [==============================] - 2s 8ms/step - loss: 2.3895 - accuracy: 0.5043 - val_loss: 2.2027 - val_accuracy: 0.7345
# Epoch 16/100
# 258/258 [==============================] - 2s 6ms/step - loss: 2.3317 - accuracy: 0.5185 - val_loss: 2.1454 - val_accuracy: 0.7277
# Epoch 17/100
# 258/258 [==============================] - 2s 7ms/step - loss: 2.2805 - accuracy: 0.5452 - val_loss: 2.0892 - val_accuracy: 0.7155
# Epoch 18/100
# 258/258 [==============================] - 2s 7ms/step - loss: 2.2280 - accuracy: 0.5530 - val_loss: 2.0378 - val_accuracy: 0.7049
# Epoch 19/100
# 258/258 [==============================] - 2s 6ms/step - loss: 2.1744 - accuracy: 0.5610 - val_loss: 1.9874 - val_accuracy: 0.7019
# Epoch 20/100
# 258/258 [==============================] - 2s 8ms/step - loss: 2.1317 - accuracy: 0.5701 - val_loss: 1.9392 - val_accuracy: 0.7005
# Epoch 21/100
# 258/258 [==============================] - 2s 7ms/step - loss: 2.0855 - accuracy: 0.5814 - val_loss: 1.8928 - val_accuracy: 0.7000
# Epoch 22/100
# 258/258 [==============================] - 2s 7ms/step - loss: 2.0385 - accuracy: 0.5962 - val_loss: 1.8480 - val_accuracy: 0.6976
# Epoch 23/100
# 258/258 [==============================] - 2s 8ms/step - loss: 1.9950 - accuracy: 0.6014 - val_loss: 1.8069 - val_accuracy: 0.7005
# Epoch 24/100
# 258/258 [==============================] - 2s 7ms/step - loss: 1.9546 - accuracy: 0.6095 - val_loss: 1.7671 - val_accuracy: 0.7034
# Epoch 25/100
# 258/258 [==============================] - 2s 7ms/step - loss: 1.9140 - accuracy: 0.6195 - val_loss: 1.7279 - val_accuracy: 0.7049
# Epoch 26/100
# 258/258 [==============================] - 2s 7ms/step - loss: 1.8757 - accuracy: 0.6347 - val_loss: 1.6916 - val_accuracy: 0.7053
# Epoch 27/100
# 258/258 [==============================] - 2s 7ms/step - loss: 1.8368 - accuracy: 0.6355 - val_loss: 1.6572 - val_accuracy: 0.7083
# Epoch 28/100
# 258/258 [==============================] - 2s 7ms/step - loss: 1.8004 - accuracy: 0.6430 - val_loss: 1.6237 - val_accuracy: 0.7083
# Epoch 29/100
# 258/258 [==============================] - 2s 8ms/step - loss: 1.7731 - accuracy: 0.6480 - val_loss: 1.5890 - val_accuracy: 0.7189
# Epoch 30/100
# 258/258 [==============================] - 2s 7ms/step - loss: 1.7439 - accuracy: 0.6467 - val_loss: 1.5587 - val_accuracy: 0.7170
# Epoch 31/100
# 258/258 [==============================] - 2s 8ms/step - loss: 1.7094 - accuracy: 0.6542 - val_loss: 1.5267 - val_accuracy: 0.7272
# Epoch 32/100
# 258/258 [==============================] - 2s 7ms/step - loss: 1.6738 - accuracy: 0.6606 - val_loss: 1.4968 - val_accuracy: 0.7340
# Epoch 33/100
# 258/258 [==============================] - 2s 7ms/step - loss: 1.6427 - accuracy: 0.6688 - val_loss: 1.4680 - val_accuracy: 0.7388
# Epoch 34/100
# 258/258 [==============================] - 2s 7ms/step - loss: 1.6127 - accuracy: 0.6775 - val_loss: 1.4397 - val_accuracy: 0.7442
# Epoch 35/100
# 258/258 [==============================] - 2s 7ms/step - loss: 1.5895 - accuracy: 0.6825 - val_loss: 1.4137 - val_accuracy: 0.7437
# Epoch 36/100
# 258/258 [==============================] - 2s 7ms/step - loss: 1.5647 - accuracy: 0.6793 - val_loss: 1.3886 - val_accuracy: 0.7481
# Epoch 37/100
# 258/258 [==============================] - 2s 8ms/step - loss: 1.5459 - accuracy: 0.6843 - val_loss: 1.3611 - val_accuracy: 0.7607
# Epoch 38/100
# 258/258 [==============================] - 2s 9ms/step - loss: 1.5198 - accuracy: 0.6842 - val_loss: 1.3393 - val_accuracy: 0.7655
# Epoch 39/100
# 258/258 [==============================] - 2s 8ms/step - loss: 1.4842 - accuracy: 0.6967 - val_loss: 1.3158 - val_accuracy: 0.7714
# Epoch 40/100
# 258/258 [==============================] - 2s 7ms/step - loss: 1.4625 - accuracy: 0.6989 - val_loss: 1.2923 - val_accuracy: 0.7782
# Epoch 41/100
# 258/258 [==============================] - 2s 7ms/step - loss: 1.4404 - accuracy: 0.7003 - val_loss: 1.2696 - val_accuracy: 0.7874
# Epoch 42/100
# 258/258 [==============================] - 2s 8ms/step - loss: 1.4154 - accuracy: 0.7109 - val_loss: 1.2494 - val_accuracy: 0.7840
# Epoch 43/100
# 258/258 [==============================] - 2s 7ms/step - loss: 1.3988 - accuracy: 0.7146 - val_loss: 1.2280 - val_accuracy: 0.7947
# Epoch 44/100
# 258/258 [==============================] - 2s 7ms/step - loss: 1.3807 - accuracy: 0.7223 - val_loss: 1.2075 - val_accuracy: 0.8015
# Epoch 45/100
# 258/258 [==============================] - 2s 8ms/step - loss: 1.3637 - accuracy: 0.7089 - val_loss: 1.1894 - val_accuracy: 0.7976
# Epoch 46/100
# 258/258 [==============================] - 2s 8ms/step - loss: 1.3376 - accuracy: 0.7233 - val_loss: 1.1702 - val_accuracy: 0.8049
# Epoch 47/100
# 258/258 [==============================] - 2s 7ms/step - loss: 1.3211 - accuracy: 0.7251 - val_loss: 1.1504 - val_accuracy: 0.8136
# Epoch 48/100
# 258/258 [==============================] - 2s 7ms/step - loss: 1.2980 - accuracy: 0.7403 - val_loss: 1.1334 - val_accuracy: 0.8155
# Epoch 49/100
# 258/258 [==============================] - 2s 7ms/step - loss: 1.2889 - accuracy: 0.7268 - val_loss: 1.1156 - val_accuracy: 0.8150
# Epoch 50/100
# 258/258 [==============================] - 2s 7ms/step - loss: 1.2640 - accuracy: 0.7373 - val_loss: 1.1008 - val_accuracy: 0.8165
# Epoch 51/100
# 258/258 [==============================] - 2s 7ms/step - loss: 1.2497 - accuracy: 0.7395 - val_loss: 1.0803 - val_accuracy: 0.8262
# Epoch 52/100
# 258/258 [==============================] - 2s 7ms/step - loss: 1.2295 - accuracy: 0.7486 - val_loss: 1.0667 - val_accuracy: 0.8257
# Epoch 53/100
# 258/258 [==============================] - 2s 7ms/step - loss: 1.2205 - accuracy: 0.7458 - val_loss: 1.0498 - val_accuracy: 0.8359
# Epoch 54/100
# 258/258 [==============================] - 2s 8ms/step - loss: 1.2030 - accuracy: 0.7501 - val_loss: 1.0352 - val_accuracy: 0.8262
# Epoch 55/100
# 258/258 [==============================] - 2s 7ms/step - loss: 1.1893 - accuracy: 0.7502 - val_loss: 1.0179 - val_accuracy: 0.8345
# Epoch 56/100
# 258/258 [==============================] - 2s 8ms/step - loss: 1.1735 - accuracy: 0.7534 - val_loss: 1.0033 - val_accuracy: 0.8388
# Epoch 57/100
# 258/258 [==============================] - 2s 7ms/step - loss: 1.1610 - accuracy: 0.7585 - val_loss: 0.9896 - val_accuracy: 0.8403
# Epoch 58/100
# 258/258 [==============================] - 2s 8ms/step - loss: 1.1430 - accuracy: 0.7627 - val_loss: 0.9747 - val_accuracy: 0.8500
# Epoch 59/100
# 258/258 [==============================] - 2s 7ms/step - loss: 1.1278 - accuracy: 0.7723 - val_loss: 0.9617 - val_accuracy: 0.8510
# Epoch 60/100
# 258/258 [==============================] - 2s 7ms/step - loss: 1.1079 - accuracy: 0.7767 - val_loss: 0.9486 - val_accuracy: 0.8558
# Epoch 61/100
# 258/258 [==============================] - 2s 7ms/step - loss: 1.0980 - accuracy: 0.7728 - val_loss: 0.9338 - val_accuracy: 0.8617
# Epoch 62/100
# 258/258 [==============================] - 2s 7ms/step - loss: 1.0823 - accuracy: 0.7812 - val_loss: 0.9223 - val_accuracy: 0.8650
# Epoch 63/100
# 258/258 [==============================] - 2s 8ms/step - loss: 1.0733 - accuracy: 0.7793 - val_loss: 0.9096 - val_accuracy: 0.8806
# Epoch 64/100
# 258/258 [==============================] - 2s 8ms/step - loss: 1.0665 - accuracy: 0.7792 - val_loss: 0.8959 - val_accuracy: 0.8748
# Epoch 65/100
# 258/258 [==============================] - 2s 8ms/step - loss: 1.0533 - accuracy: 0.7831 - val_loss: 0.8833 - val_accuracy: 0.8772
# Epoch 66/100
# 258/258 [==============================] - 2s 7ms/step - loss: 1.0374 - accuracy: 0.7850 - val_loss: 0.8736 - val_accuracy: 0.8879
# Epoch 67/100
# 258/258 [==============================] - 2s 7ms/step - loss: 1.0242 - accuracy: 0.7960 - val_loss: 0.8621 - val_accuracy: 0.8874
# Epoch 68/100
# 258/258 [==============================] - 2s 7ms/step - loss: 1.0129 - accuracy: 0.7962 - val_loss: 0.8514 - val_accuracy: 0.8990
# Epoch 69/100
# 258/258 [==============================] - 2s 8ms/step - loss: 0.9974 - accuracy: 0.7951 - val_loss: 0.8385 - val_accuracy: 0.9068
# Epoch 70/100
# 258/258 [==============================] - 2s 6ms/step - loss: 0.9895 - accuracy: 0.8058 - val_loss: 0.8267 - val_accuracy: 0.9049
# Epoch 71/100
# 258/258 [==============================] - 2s 7ms/step - loss: 0.9761 - accuracy: 0.8007 - val_loss: 0.8165 - val_accuracy: 0.9150
# Epoch 72/100
# 258/258 [==============================] - 2s 6ms/step - loss: 0.9767 - accuracy: 0.8047 - val_loss: 0.8048 - val_accuracy: 0.9218
# Epoch 73/100
# 258/258 [==============================] - 2s 6ms/step - loss: 0.9663 - accuracy: 0.8098 - val_loss: 0.7952 - val_accuracy: 0.9248
# Epoch 74/100
# 258/258 [==============================] - 2s 8ms/step - loss: 0.9539 - accuracy: 0.8091 - val_loss: 0.7842 - val_accuracy: 0.9301
# Epoch 75/100
# 258/258 [==============================] - 2s 7ms/step - loss: 0.9436 - accuracy: 0.8159 - val_loss: 0.7768 - val_accuracy: 0.9296
# Epoch 76/100
# 258/258 [==============================] - 2s 7ms/step - loss: 0.9383 - accuracy: 0.8104 - val_loss: 0.7660 - val_accuracy: 0.9398
# Epoch 77/100
# 258/258 [==============================] - 2s 7ms/step - loss: 0.9314 - accuracy: 0.8111 - val_loss: 0.7579 - val_accuracy: 0.9422
# Epoch 78/100
# 258/258 [==============================] - 3s 11ms/step - loss: 0.9057 - accuracy: 0.8276 - val_loss: 0.7462 - val_accuracy: 0.9408
# Epoch 79/100
# 258/258 [==============================] - 3s 10ms/step - loss: 0.9059 - accuracy: 0.8206 - val_loss: 0.7383 - val_accuracy: 0.9432
# Epoch 80/100
# 258/258 [==============================] - 2s 7ms/step - loss: 0.8966 - accuracy: 0.8284 - val_loss: 0.7281 - val_accuracy: 0.9432
# Epoch 81/100
# 258/258 [==============================] - 2s 9ms/step - loss: 0.8893 - accuracy: 0.8256 - val_loss: 0.7204 - val_accuracy: 0.9490
# Epoch 82/100
# 258/258 [==============================] - 2s 9ms/step - loss: 0.8739 - accuracy: 0.8266 - val_loss: 0.7093 - val_accuracy: 0.9500
# Epoch 83/100
# 258/258 [==============================] - 3s 10ms/step - loss: 0.8750 - accuracy: 0.8291 - val_loss: 0.7024 - val_accuracy: 0.9563
# Epoch 84/100
# 258/258 [==============================] - 2s 8ms/step - loss: 0.8591 - accuracy: 0.8360 - val_loss: 0.6933 - val_accuracy: 0.9553
# Epoch 85/100
# 258/258 [==============================] - 2s 7ms/step - loss: 0.8613 - accuracy: 0.8324 - val_loss: 0.6851 - val_accuracy: 0.9602
# Epoch 86/100
# 258/258 [==============================] - 2s 7ms/step - loss: 0.8422 - accuracy: 0.8418 - val_loss: 0.6765 - val_accuracy: 0.9617
# Epoch 87/100
# 258/258 [==============================] - 2s 8ms/step - loss: 0.8365 - accuracy: 0.8439 - val_loss: 0.6676 - val_accuracy: 0.9636
# Epoch 88/100
# 258/258 [==============================] - 2s 7ms/step - loss: 0.8243 - accuracy: 0.8484 - val_loss: 0.6588 - val_accuracy: 0.9641
# Epoch 89/100
# 258/258 [==============================] - 2s 8ms/step - loss: 0.8143 - accuracy: 0.8536 - val_loss: 0.6519 - val_accuracy: 0.9636
# Epoch 90/100
# 258/258 [==============================] - 2s 7ms/step - loss: 0.8142 - accuracy: 0.8459 - val_loss: 0.6442 - val_accuracy: 0.9646
# Epoch 91/100
# 258/258 [==============================] - 2s 8ms/step - loss: 0.8156 - accuracy: 0.8513 - val_loss: 0.6353 - val_accuracy: 0.9670
# Epoch 92/100
# 258/258 [==============================] - 2s 6ms/step - loss: 0.7990 - accuracy: 0.8550 - val_loss: 0.6281 - val_accuracy: 0.9689
# Epoch 93/100
# 258/258 [==============================] - 2s 8ms/step - loss: 0.7964 - accuracy: 0.8525 - val_loss: 0.6218 - val_accuracy: 0.9665
# Epoch 94/100
# 258/258 [==============================] - 2s 7ms/step - loss: 0.7808 - accuracy: 0.8639 - val_loss: 0.6143 - val_accuracy: 0.9694
# Epoch 95/100
# 258/258 [==============================] - 2s 8ms/step - loss: 0.7720 - accuracy: 0.8643 - val_loss: 0.6060 - val_accuracy: 0.9689
# Epoch 96/100
# 258/258 [==============================] - 2s 7ms/step - loss: 0.7751 - accuracy: 0.8621 - val_loss: 0.5986 - val_accuracy: 0.9714
# Epoch 97/100
# 258/258 [==============================] - 2s 7ms/step - loss: 0.7627 - accuracy: 0.8698 - val_loss: 0.5926 - val_accuracy: 0.9699
# Epoch 98/100
# 258/258 [==============================] - 2s 7ms/step - loss: 0.7587 - accuracy: 0.8610 - val_loss: 0.5878 - val_accuracy: 0.9680
# Epoch 99/100
# 258/258 [==============================] - 2s 8ms/step - loss: 0.7498 - accuracy: 0.8665 - val_loss: 0.5791 - val_accuracy: 0.9699
# Epoch 100/100
# 258/258 [==============================] - 2s 7ms/step - loss: 0.7481 - accuracy: 0.8670 - val_loss: 0.5751 - val_accuracy: 0.9704
# Training with SGD optimizer...
# Epoch 1/100
# 258/258 [==============================] - 11s 14ms/step - loss: 3.6461 - accuracy: 0.1913 - val_loss: 3.6059 - val_accuracy: 0.3791
# Epoch 2/100
# 258/258 [==============================] - 2s 8ms/step - loss: 3.6125 - accuracy: 0.2126 - val_loss: 3.5625 - val_accuracy: 0.4364
# Epoch 3/100
# 258/258 [==============================] - 3s 10ms/step - loss: 3.5762 - accuracy: 0.2296 - val_loss: 3.5238 - val_accuracy: 0.4680
# Epoch 4/100
# 258/258 [==============================] - 3s 10ms/step - loss: 3.5468 - accuracy: 0.2591 - val_loss: 3.4852 - val_accuracy: 0.4903
# Epoch 5/100
# 258/258 [==============================] - 3s 10ms/step - loss: 3.5115 - accuracy: 0.2778 - val_loss: 3.4474 - val_accuracy: 0.5087
# Epoch 6/100
# 258/258 [==============================] - 2s 8ms/step - loss: 3.4767 - accuracy: 0.2971 - val_loss: 3.4081 - val_accuracy: 0.5282
# Epoch 7/100
# 258/258 [==============================] - 3s 11ms/step - loss: 3.4443 - accuracy: 0.3131 - val_loss: 3.3680 - val_accuracy: 0.5519
# Epoch 8/100
# 258/258 [==============================] - 2s 9ms/step - loss: 3.4097 - accuracy: 0.3239 - val_loss: 3.3258 - val_accuracy: 0.5636
# Epoch 9/100
# 258/258 [==============================] - 2s 9ms/step - loss: 3.3698 - accuracy: 0.3491 - val_loss: 3.2810 - val_accuracy: 0.5583
# Epoch 10/100
# 258/258 [==============================] - 2s 9ms/step - loss: 3.3350 - accuracy: 0.3530 - val_loss: 3.2358 - val_accuracy: 0.5714
# Epoch 11/100
# 258/258 [==============================] - 2s 7ms/step - loss: 3.2970 - accuracy: 0.3718 - val_loss: 3.1892 - val_accuracy: 0.5733
# Epoch 12/100
# 258/258 [==============================] - 2s 7ms/step - loss: 3.2494 - accuracy: 0.3934 - val_loss: 3.1392 - val_accuracy: 0.5801
# Epoch 13/100
# 258/258 [==============================] - 2s 7ms/step - loss: 3.2076 - accuracy: 0.4071 - val_loss: 3.0885 - val_accuracy: 0.5874
# Epoch 14/100
# 258/258 [==============================] - 2s 7ms/step - loss: 3.1610 - accuracy: 0.4258 - val_loss: 3.0372 - val_accuracy: 0.5932
# Epoch 15/100
# 258/258 [==============================] - 2s 7ms/step - loss: 3.1208 - accuracy: 0.4258 - val_loss: 2.9855 - val_accuracy: 0.5864
# Epoch 16/100
# 258/258 [==============================] - 2s 8ms/step - loss: 3.0762 - accuracy: 0.4407 - val_loss: 2.9329 - val_accuracy: 0.5864
# Epoch 17/100
# 258/258 [==============================] - 2s 7ms/step - loss: 3.0238 - accuracy: 0.4621 - val_loss: 2.8792 - val_accuracy: 0.5835
# Epoch 18/100
# 258/258 [==============================] - 2s 7ms/step - loss: 2.9851 - accuracy: 0.4677 - val_loss: 2.8274 - val_accuracy: 0.6005
# Epoch 19/100
# 258/258 [==============================] - 2s 6ms/step - loss: 2.9362 - accuracy: 0.4759 - val_loss: 2.7759 - val_accuracy: 0.6058
# Epoch 20/100
# 258/258 [==============================] - 2s 7ms/step - loss: 2.8880 - accuracy: 0.4879 - val_loss: 2.7264 - val_accuracy: 0.6199
# Epoch 21/100
# 258/258 [==============================] - 2s 7ms/step - loss: 2.8464 - accuracy: 0.5013 - val_loss: 2.6747 - val_accuracy: 0.6320
# Epoch 22/100
# 258/258 [==============================] - 2s 7ms/step - loss: 2.7995 - accuracy: 0.5103 - val_loss: 2.6260 - val_accuracy: 0.6354
# Epoch 23/100
# 258/258 [==============================] - 2s 7ms/step - loss: 2.7587 - accuracy: 0.5178 - val_loss: 2.5790 - val_accuracy: 0.6403
# Epoch 24/100
# 258/258 [==============================] - 2s 7ms/step - loss: 2.7242 - accuracy: 0.5189 - val_loss: 2.5333 - val_accuracy: 0.6505
# Epoch 25/100
# 258/258 [==============================] - 2s 7ms/step - loss: 2.6801 - accuracy: 0.5276 - val_loss: 2.4872 - val_accuracy: 0.6534
# Epoch 26/100
# 258/258 [==============================] - 2s 7ms/step - loss: 2.6443 - accuracy: 0.5379 - val_loss: 2.4430 - val_accuracy: 0.6583
# Epoch 27/100
# 258/258 [==============================] - 2s 7ms/step - loss: 2.6067 - accuracy: 0.5480 - val_loss: 2.3985 - val_accuracy: 0.6607
# Epoch 28/100
# 258/258 [==============================] - 2s 7ms/step - loss: 2.5643 - accuracy: 0.5468 - val_loss: 2.3563 - val_accuracy: 0.6646
# Epoch 29/100
# 258/258 [==============================] - 2s 8ms/step - loss: 2.5220 - accuracy: 0.5714 - val_loss: 2.3139 - val_accuracy: 0.6665
# Epoch 30/100
# 258/258 [==============================] - 2s 7ms/step - loss: 2.4911 - accuracy: 0.5757 - val_loss: 2.2733 - val_accuracy: 0.6689
# Epoch 31/100
# 258/258 [==============================] - 2s 7ms/step - loss: 2.4493 - accuracy: 0.5876 - val_loss: 2.2324 - val_accuracy: 0.6699
# Epoch 32/100
# 258/258 [==============================] - 2s 7ms/step - loss: 2.4206 - accuracy: 0.5955 - val_loss: 2.1933 - val_accuracy: 0.6714
# Epoch 33/100
# 258/258 [==============================] - 2s 8ms/step - loss: 2.3792 - accuracy: 0.6075 - val_loss: 2.1523 - val_accuracy: 0.6738
# Epoch 34/100
# 258/258 [==============================] - 2s 6ms/step - loss: 2.3455 - accuracy: 0.6050 - val_loss: 2.1149 - val_accuracy: 0.6762
# Epoch 35/100
# 258/258 [==============================] - 2s 7ms/step - loss: 2.3088 - accuracy: 0.6123 - val_loss: 2.0797 - val_accuracy: 0.6772
# Epoch 36/100
# 258/258 [==============================] - 2s 8ms/step - loss: 2.2814 - accuracy: 0.6148 - val_loss: 2.0436 - val_accuracy: 0.6777
# Epoch 37/100
# 258/258 [==============================] - 2s 7ms/step - loss: 2.2417 - accuracy: 0.6217 - val_loss: 2.0089 - val_accuracy: 0.6796
# Epoch 38/100
# 258/258 [==============================] - 2s 7ms/step - loss: 2.2151 - accuracy: 0.6294 - val_loss: 1.9769 - val_accuracy: 0.6840
# Epoch 39/100
# 258/258 [==============================] - 2s 6ms/step - loss: 2.1841 - accuracy: 0.6290 - val_loss: 1.9454 - val_accuracy: 0.6859
# Epoch 40/100
# 258/258 [==============================] - 2s 7ms/step - loss: 2.1590 - accuracy: 0.6360 - val_loss: 1.9156 - val_accuracy: 0.6908
# Epoch 41/100
# 258/258 [==============================] - 2s 7ms/step - loss: 2.1247 - accuracy: 0.6441 - val_loss: 1.8884 - val_accuracy: 0.6927
# Epoch 42/100
# 258/258 [==============================] - 2s 7ms/step - loss: 2.0977 - accuracy: 0.6407 - val_loss: 1.8600 - val_accuracy: 0.6947
# Epoch 43/100
# 258/258 [==============================] - 2s 6ms/step - loss: 2.0700 - accuracy: 0.6507 - val_loss: 1.8347 - val_accuracy: 0.6951
# Epoch 44/100
# 258/258 [==============================] - 2s 7ms/step - loss: 2.0425 - accuracy: 0.6484 - val_loss: 1.8082 - val_accuracy: 0.6971
# Epoch 45/100
# 258/258 [==============================] - 2s 7ms/step - loss: 2.0172 - accuracy: 0.6537 - val_loss: 1.7844 - val_accuracy: 0.6985
# Epoch 46/100
# 258/258 [==============================] - 2s 8ms/step - loss: 1.9922 - accuracy: 0.6586 - val_loss: 1.7611 - val_accuracy: 0.7019
# Epoch 47/100
# 258/258 [==============================] - 2s 8ms/step - loss: 1.9700 - accuracy: 0.6557 - val_loss: 1.7406 - val_accuracy: 0.6990
# Epoch 48/100
# 258/258 [==============================] - 2s 7ms/step - loss: 1.9422 - accuracy: 0.6659 - val_loss: 1.7202 - val_accuracy: 0.7000
# Epoch 49/100
# 258/258 [==============================] - 2s 8ms/step - loss: 1.9227 - accuracy: 0.6639 - val_loss: 1.7037 - val_accuracy: 0.6985
# Epoch 50/100
# 258/258 [==============================] - 2s 7ms/step - loss: 1.9037 - accuracy: 0.6655 - val_loss: 1.6820 - val_accuracy: 0.7029
# Epoch 51/100
# 258/258 [==============================] - 2s 7ms/step - loss: 1.8717 - accuracy: 0.6744 - val_loss: 1.6635 - val_accuracy: 0.7044
# Epoch 52/100
# 258/258 [==============================] - 2s 7ms/step - loss: 1.8531 - accuracy: 0.6711 - val_loss: 1.6466 - val_accuracy: 0.7034
# Epoch 53/100
# 258/258 [==============================] - 2s 8ms/step - loss: 1.8378 - accuracy: 0.6731 - val_loss: 1.6286 - val_accuracy: 0.7112
# Epoch 54/100
# 258/258 [==============================] - 2s 7ms/step - loss: 1.8211 - accuracy: 0.6735 - val_loss: 1.6130 - val_accuracy: 0.7058
# Epoch 55/100
# 258/258 [==============================] - 2s 7ms/step - loss: 1.7976 - accuracy: 0.6767 - val_loss: 1.5966 - val_accuracy: 0.7117
# Epoch 56/100
# 258/258 [==============================] - 2s 7ms/step - loss: 1.7835 - accuracy: 0.6803 - val_loss: 1.5834 - val_accuracy: 0.7112
# Epoch 57/100
# 258/258 [==============================] - 2s 8ms/step - loss: 1.7606 - accuracy: 0.6845 - val_loss: 1.5677 - val_accuracy: 0.7112
# Epoch 58/100
# 258/258 [==============================] - 2s 7ms/step - loss: 1.7414 - accuracy: 0.6876 - val_loss: 1.5533 - val_accuracy: 0.7204
# Epoch 59/100
# 258/258 [==============================] - 2s 7ms/step - loss: 1.7272 - accuracy: 0.6912 - val_loss: 1.5394 - val_accuracy: 0.7180
# Epoch 60/100
# 258/258 [==============================] - 2s 7ms/step - loss: 1.7088 - accuracy: 0.6899 - val_loss: 1.5254 - val_accuracy: 0.7296
# Epoch 61/100
# 258/258 [==============================] - 2s 7ms/step - loss: 1.6923 - accuracy: 0.6839 - val_loss: 1.5119 - val_accuracy: 0.7291
# Epoch 62/100
# 258/258 [==============================] - 2s 7ms/step - loss: 1.6826 - accuracy: 0.6858 - val_loss: 1.4984 - val_accuracy: 0.7335
# Epoch 63/100
# 258/258 [==============================] - 2s 7ms/step - loss: 1.6561 - accuracy: 0.7045 - val_loss: 1.4848 - val_accuracy: 0.7359
# Epoch 64/100
# 258/258 [==============================] - 2s 7ms/step - loss: 1.6484 - accuracy: 0.6960 - val_loss: 1.4737 - val_accuracy: 0.7335
# Epoch 65/100
# 258/258 [==============================] - 2s 7ms/step - loss: 1.6344 - accuracy: 0.6945 - val_loss: 1.4624 - val_accuracy: 0.7359
# Epoch 66/100
# 258/258 [==============================] - 2s 8ms/step - loss: 1.6145 - accuracy: 0.7008 - val_loss: 1.4481 - val_accuracy: 0.7515
# Epoch 67/100
# 258/258 [==============================] - 2s 7ms/step - loss: 1.6016 - accuracy: 0.7071 - val_loss: 1.4363 - val_accuracy: 0.7519
# Epoch 68/100
# 258/258 [==============================] - 2s 8ms/step - loss: 1.5835 - accuracy: 0.7082 - val_loss: 1.4239 - val_accuracy: 0.7519
# Epoch 69/100
# 258/258 [==============================] - 2s 7ms/step - loss: 1.5704 - accuracy: 0.7139 - val_loss: 1.4115 - val_accuracy: 0.7650
# Epoch 70/100
# 258/258 [==============================] - 2s 7ms/step - loss: 1.5582 - accuracy: 0.7098 - val_loss: 1.4020 - val_accuracy: 0.7592
# Epoch 71/100
# 258/258 [==============================] - 2s 7ms/step - loss: 1.5435 - accuracy: 0.7130 - val_loss: 1.3878 - val_accuracy: 0.7883
# Epoch 72/100
# 258/258 [==============================] - 2s 7ms/step - loss: 1.5330 - accuracy: 0.7159 - val_loss: 1.3766 - val_accuracy: 0.7927
# Epoch 73/100
# 258/258 [==============================] - 2s 8ms/step - loss: 1.5248 - accuracy: 0.7187 - val_loss: 1.3667 - val_accuracy: 0.7883
# Epoch 74/100
# 258/258 [==============================] - 2s 7ms/step - loss: 1.5066 - accuracy: 0.7210 - val_loss: 1.3541 - val_accuracy: 0.7976
# Epoch 75/100
# 258/258 [==============================] - 2s 8ms/step - loss: 1.4920 - accuracy: 0.7177 - val_loss: 1.3424 - val_accuracy: 0.7990
# Epoch 76/100
# 258/258 [==============================] - 2s 7ms/step - loss: 1.4827 - accuracy: 0.7278 - val_loss: 1.3305 - val_accuracy: 0.8141
# Epoch 77/100
# 258/258 [==============================] - 2s 8ms/step - loss: 1.4753 - accuracy: 0.7227 - val_loss: 1.3205 - val_accuracy: 0.8218
# Epoch 78/100
# 258/258 [==============================] - 2s 7ms/step - loss: 1.4566 - accuracy: 0.7316 - val_loss: 1.3088 - val_accuracy: 0.8345
# Epoch 79/100
# 258/258 [==============================] - 2s 7ms/step - loss: 1.4451 - accuracy: 0.7281 - val_loss: 1.2976 - val_accuracy: 0.8306
# Epoch 80/100
# 258/258 [==============================] - 2s 7ms/step - loss: 1.4288 - accuracy: 0.7350 - val_loss: 1.2880 - val_accuracy: 0.8350
# Epoch 81/100
# 258/258 [==============================] - 2s 8ms/step - loss: 1.4243 - accuracy: 0.7350 - val_loss: 1.2757 - val_accuracy: 0.8311
# Epoch 82/100
# 258/258 [==============================] - 2s 7ms/step - loss: 1.4125 - accuracy: 0.7348 - val_loss: 1.2664 - val_accuracy: 0.8267
# Epoch 83/100
# 258/258 [==============================] - 2s 8ms/step - loss: 1.3968 - accuracy: 0.7440 - val_loss: 1.2542 - val_accuracy: 0.8364
# Epoch 84/100
# 258/258 [==============================] - 2s 7ms/step - loss: 1.3843 - accuracy: 0.7474 - val_loss: 1.2439 - val_accuracy: 0.8296
# Epoch 85/100
# 258/258 [==============================] - 2s 7ms/step - loss: 1.3794 - accuracy: 0.7434 - val_loss: 1.2327 - val_accuracy: 0.8485
# Epoch 86/100
# 258/258 [==============================] - 2s 7ms/step - loss: 1.3643 - accuracy: 0.7445 - val_loss: 1.2214 - val_accuracy: 0.8515
# Epoch 87/100
# 258/258 [==============================] - 2s 7ms/step - loss: 1.3561 - accuracy: 0.7477 - val_loss: 1.2105 - val_accuracy: 0.8456
# Epoch 88/100
# 258/258 [==============================] - 2s 7ms/step - loss: 1.3461 - accuracy: 0.7498 - val_loss: 1.1979 - val_accuracy: 0.8655
# Epoch 89/100
# 258/258 [==============================] - 2s 7ms/step - loss: 1.3274 - accuracy: 0.7603 - val_loss: 1.1880 - val_accuracy: 0.8767
# Epoch 90/100
# 258/258 [==============================] - 2s 7ms/step - loss: 1.3206 - accuracy: 0.7602 - val_loss: 1.1756 - val_accuracy: 0.8845
# Epoch 91/100
# 258/258 [==============================] - 2s 7ms/step - loss: 1.3053 - accuracy: 0.7640 - val_loss: 1.1644 - val_accuracy: 0.8874
# Epoch 92/100
# 258/258 [==============================] - 2s 7ms/step - loss: 1.2924 - accuracy: 0.7678 - val_loss: 1.1516 - val_accuracy: 0.8898
# Epoch 93/100
# 258/258 [==============================] - 2s 7ms/step - loss: 1.2817 - accuracy: 0.7762 - val_loss: 1.1412 - val_accuracy: 0.8981
# Epoch 94/100
# 258/258 [==============================] - 2s 8ms/step - loss: 1.2695 - accuracy: 0.7819 - val_loss: 1.1320 - val_accuracy: 0.8947
# Epoch 95/100
# 258/258 [==============================] - 2s 7ms/step - loss: 1.2541 - accuracy: 0.7833 - val_loss: 1.1191 - val_accuracy: 0.9107
# Epoch 96/100
# 258/258 [==============================] - 2s 8ms/step - loss: 1.2546 - accuracy: 0.7744 - val_loss: 1.1073 - val_accuracy: 0.9141
# Epoch 97/100
# 258/258 [==============================] - 2s 7ms/step - loss: 1.2337 - accuracy: 0.7937 - val_loss: 1.0943 - val_accuracy: 0.9121
# Epoch 98/100
# 258/258 [==============================] - 2s 7ms/step - loss: 1.2305 - accuracy: 0.7912 - val_loss: 1.0855 - val_accuracy: 0.9257
# Epoch 99/100
# 258/258 [==============================] - 2s 8ms/step - loss: 1.2154 - accuracy: 0.7941 - val_loss: 1.0730 - val_accuracy: 0.9150
# Epoch 100/100
# 258/258 [==============================] - 2s 7ms/step - loss: 1.2063 - accuracy: 0.7965 - val_loss: 1.0626 - val_accuracy: 0.9316
# Training with RMSprop optimizer...
# Epoch 1/100
# 258/258 [==============================] - 24s 16ms/step - loss: 1.4927 - accuracy: 0.5966 - val_loss: 0.6316 - val_accuracy: 0.8049
# Epoch 2/100
# 258/258 [==============================] - 2s 9ms/step - loss: 0.6347 - accuracy: 0.8110 - val_loss: 0.4400 - val_accuracy: 0.9238
# Epoch 3/100
# 258/258 [==============================] - 2s 8ms/step - loss: 0.5084 - accuracy: 0.8632 - val_loss: 0.2861 - val_accuracy: 0.9592
# Epoch 4/100
# 258/258 [==============================] - 2s 6ms/step - loss: 0.4304 - accuracy: 0.8917 - val_loss: 0.2712 - val_accuracy: 0.9485
# Epoch 5/100
# 258/258 [==============================] - 3s 10ms/step - loss: 0.3917 - accuracy: 0.9130 - val_loss: 0.2743 - val_accuracy: 0.9383
# Epoch 6/100
# 258/258 [==============================] - 2s 7ms/step - loss: 0.3510 - accuracy: 0.9245 - val_loss: 0.4029 - val_accuracy: 0.8898
# Epoch 7/100
# 258/258 [==============================] - 2s 7ms/step - loss: 0.3318 - accuracy: 0.9330 - val_loss: 0.2175 - val_accuracy: 0.9607
# Epoch 8/100
# 258/258 [==============================] - 2s 7ms/step - loss: 0.3194 - accuracy: 0.9324 - val_loss: 0.2077 - val_accuracy: 0.9728
# Epoch 9/100
# 258/258 [==============================] - 2s 7ms/step - loss: 0.3196 - accuracy: 0.9322 - val_loss: 0.1638 - val_accuracy: 0.9816
# Epoch 10/100
# 258/258 [==============================] - 2s 7ms/step - loss: 0.3104 - accuracy: 0.9369 - val_loss: 0.2271 - val_accuracy: 0.9583
# Epoch 11/100
# 258/258 [==============================] - 2s 7ms/step - loss: 0.3056 - accuracy: 0.9379 - val_loss: 0.2095 - val_accuracy: 0.9636
# Epoch 12/100
# 258/258 [==============================] - 2s 6ms/step - loss: 0.3108 - accuracy: 0.9341 - val_loss: 0.1739 - val_accuracy: 0.9806
# Epoch 13/100
# 258/258 [==============================] - 2s 6ms/step - loss: 0.3119 - accuracy: 0.9343 - val_loss: 0.1823 - val_accuracy: 0.9816
# Epoch 14/100
# 258/258 [==============================] - 2s 7ms/step - loss: 0.3026 - accuracy: 0.9392 - val_loss: 0.1662 - val_accuracy: 0.9811
# Epoch 15/100
# 258/258 [==============================] - 2s 6ms/step - loss: 0.2993 - accuracy: 0.9386 - val_loss: 0.1476 - val_accuracy: 0.9879
# Epoch 16/100
# 258/258 [==============================] - 2s 7ms/step - loss: 0.2970 - accuracy: 0.9398 - val_loss: 0.1504 - val_accuracy: 0.9845
# Epoch 17/100
# 258/258 [==============================] - 2s 7ms/step - loss: 0.3001 - accuracy: 0.9389 - val_loss: 0.1721 - val_accuracy: 0.9762
# Epoch 18/100
# 258/258 [==============================] - 2s 7ms/step - loss: 0.2796 - accuracy: 0.9444 - val_loss: 0.1579 - val_accuracy: 0.9816
# Epoch 19/100
# 258/258 [==============================] - 2s 7ms/step - loss: 0.2876 - accuracy: 0.9408 - val_loss: 0.1624 - val_accuracy: 0.9806
# Epoch 20/100
# 258/258 [==============================] - 2s 6ms/step - loss: 0.2914 - accuracy: 0.9372 - val_loss: 0.1802 - val_accuracy: 0.9704
# Epoch 21/100
# 258/258 [==============================] - 2s 9ms/step - loss: 0.3092 - accuracy: 0.9317 - val_loss: 0.4166 - val_accuracy: 0.8665
# Epoch 22/100
# 258/258 [==============================] - 2s 7ms/step - loss: 0.2937 - accuracy: 0.9336 - val_loss: 0.1559 - val_accuracy: 0.9874
# Epoch 23/100
# 258/258 [==============================] - 2s 9ms/step - loss: 0.3035 - accuracy: 0.9337 - val_loss: 0.1420 - val_accuracy: 0.9898
# Epoch 24/100
# 258/258 [==============================] - 2s 7ms/step - loss: 0.2914 - accuracy: 0.9371 - val_loss: 0.1433 - val_accuracy: 0.9864
# Epoch 25/100
# 258/258 [==============================] - 2s 8ms/step - loss: 0.3049 - accuracy: 0.9379 - val_loss: 0.2746 - val_accuracy: 0.9311
# Epoch 26/100
# 258/258 [==============================] - 2s 8ms/step - loss: 0.2865 - accuracy: 0.9402 - val_loss: 0.1714 - val_accuracy: 0.9714
# Epoch 27/100
# 258/258 [==============================] - 3s 12ms/step - loss: 0.2764 - accuracy: 0.9437 - val_loss: 0.1742 - val_accuracy: 0.9791
# Epoch 28/100
# 258/258 [==============================] - 2s 8ms/step - loss: 0.2778 - accuracy: 0.9436 - val_loss: 0.2246 - val_accuracy: 0.9539
# Epoch 29/100
# 258/258 [==============================] - 2s 7ms/step - loss: 0.2702 - accuracy: 0.9467 - val_loss: 0.1509 - val_accuracy: 0.9850
# Epoch 30/100
# 258/258 [==============================] - 2s 7ms/step - loss: 0.3038 - accuracy: 0.9349 - val_loss: 0.3636 - val_accuracy: 0.8947
# Epoch 31/100
# 258/258 [==============================] - 2s 7ms/step - loss: 0.2870 - accuracy: 0.9405 - val_loss: 0.1424 - val_accuracy: 0.9874
# Epoch 32/100
# 258/258 [==============================] - 2s 7ms/step - loss: 0.2803 - accuracy: 0.9392 - val_loss: 0.1461 - val_accuracy: 0.9859
# Epoch 33/100
# 258/258 [==============================] - 2s 8ms/step - loss: 0.2827 - accuracy: 0.9413 - val_loss: 0.2000 - val_accuracy: 0.9694

# %%
# Combine all plots for comparison
plt.figure(figsize=(14, 10))
# Plot training accuracy
plt.subplot(2, 1, 1)
for opt_name, history in histories.items():
    plt.plot(history.history['accuracy'], label=f'{opt_name} Train')
    plt.plot(history.history['val_accuracy'], linestyle='--', label=f'{opt_name} Validation')
plt.title('Training & Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Plot training loss
plt.subplot(2, 1, 2)
for opt_name, history in histories.items():
    plt.plot(history.history['loss'], label=f'{opt_name} Train')
    plt.plot(history.history['val_loss'], linestyle='--', label=f'{opt_name} Validation')
plt.title('Training & Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()
